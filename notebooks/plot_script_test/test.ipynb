# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
coefficients = np.load("/Users/ciprianbangu/Cogmaster/M2 Internship/BCI code/plot_script_test/BCOM_01_ti_66_coefficients.npy", mmap_mode='r')
coefficients.shape
# Out:
# (6, 247, 100, 241)

# %%
plt.pcolormesh(coefficients[1, 0, :, :])
